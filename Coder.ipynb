# %%
import pandas as pd


#llama methodo read_csv de panda
df_frame = pd.read_csv('listings.csv')

# %%
#trae solo los primeros 20
df_frame.head(20)
# Out:
#                     id                                      listing_url  \
# 0   639280827847650582  https://www.airbnb.com/rooms/639280827847650582
# 1             33712571            https://www.airbnb.com/rooms/33712571
# 2             32934967            https://www.airbnb.com/rooms/32934967
# 3             42042076            https://www.airbnb.com/rooms/42042076
# 4             33424822            https://www.airbnb.com/rooms/33424822
# 5   641528995442730912  https://www.airbnb.com/rooms/641528995442730912
# 6             54019695            https://www.airbnb.com/rooms/54019695
# 7             32204376            https://www.airbnb.com/rooms/32204376
# 8              4338028             https://www.airbnb.com/rooms/4338028
# 9                11508               https://www.airbnb.com/rooms/11508
# 10               13095               https://www.airbnb.com/rooms/13095
# 11              108284              https://www.airbnb.com/rooms/108284
# ...

# %%
#cant de columnas y datos
df_frame.shape
# Out:
# (16195, 74)

# %%
df_frame[['name', 'calculated_host_listings_count']]
# Out:
#                                                     name  \
# 0                      Lugar encantador en vicente lopez
# 1                         Ambiente familiar....tranquilo
# 2                  Habitacion para viajeros, estudiantes
# 3                                    Hotel Vicente Lopez
# 4              Departamento de 2 ambientes frente al río
# ...                                                  ...
# 16190                       Room in a residential place.
# 16191                                Diseño, paz y amor.
# 16192                                              Hogar
# 16193  Casona de espíritu artístico y Piscina climati...
# 16194  Excelente Depto en torre PILETA GIMNASIO VISTA...
#
#        calculated_host_listings_count
# 0                                   1
# 1                                   1
# 2                                   1
# 3                                   2
# 4                                  15
# ...                               ...
# ...

# %%
#promedio de columna
df_frame['minimum_nights'].mean()
# Out:
# 7.960728619944427

# %%
#Estadisticas de todas las columnas
df_frame['calendar_updated'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: calendar_updated, dtype: float64

# %%
df_frame['price']
# Out:
# 0         $2,880.00
# 1         $1,230.00
# 2         $3,697.00
# 3         $5,500.00
# 4         $1,915.00
#             ...
# 16190     $1,230.00
# 16191    $12,323.00
# 16192     $1,230.00
# 16193     $2,500.00
# 16194    $11,091.00
# Name: price, Length: 16195, dtype: object
